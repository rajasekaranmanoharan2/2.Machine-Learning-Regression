# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_random_forest.sav",'rb'))
result=loaded_model.predict([[18,25,0,1,0]])

# %%
result
# Out:
# array([15782.64])
